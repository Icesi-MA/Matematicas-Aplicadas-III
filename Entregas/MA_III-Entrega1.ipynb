# %% [markdown]
# # Entrega 1
#
# **Departamento de Ciencias Físicas, Exactas & Energía / FIDCA**
#
# <!--
# Copyright © Angela Villota y Aníbal Sosa.
#
# El contenido textual está licenciado bajo Creative Commons
# Attribution-NonCommercial 4.0 International (CC BY-NC 4.0).
#
# El código y la lógica de los notebooks están licenciados bajo
# PolyForm Noncommercial License 1.0.0.
#
# Consulte el archivo LICENSE del repositorio para conocer los términos completos.
# -->

# %% [markdown]
# A continuación se le pide responder por grupo las siguientes preguntas, utilizando una copia del presente cuaderno para consignar todas sus respuestas con el formato requerido.
#
# La entrega está para el día **viernes 13 de Febrero** y dos **grupos** estarán encargados de socializar sus resultados de acuerdo a los lineamientos entregados en la sesión del miércoles anterior.
#
# **<u>Preguntas</u>**
#
# A continuación encuentra separadas por celda cada pregunta, así usted solo debe continuar escribiendo en la celda para dar cada respuesta. No olvide que todas sus respuestas deben ir acompañadas de al menos un argumento geométrico o numérico y uno algebráico o en lenguaje natural.
#
# **Recuerde que este cuaderno debe de ser marcado con los nombres de los integrantes, esta entrega solo se recibirá en formato ipynb. El nombre de este cuaderno debe ser Grupo_numerodelgrupo_Entrega_1.ipynb**

# %% [markdown]
# Nombre1 - Codigo1- gmail1
#
# Nombre2 - Codigo2- gmail2
#
# Nombre3 - Codigo3- gmail3
#
# Nombre4 - Codigo4- gmail4

# %% [markdown]
# 1. (10 ptos) *Integrales iteradas.*
#
#   Halle el valor de las siguientes integral iteradas: $$i)\,\int\int_{R_1} y \sin(xy)\, dx dy, \quad ii)\,\int\int_{R_2} \,\frac{x}{y}+ \frac{y}{x}\, dx dy$$ donde $R_{1}=[1,2]\times[0,\pi] \,y\, R_{2}=[1,2]\times[1,3]$.
#
#    $$iii)\,\int\int_R \cos(x) \sin^{2}(x)\sin y\, dx dy, \quad iv)\,\int\int_R \,\frac{x}{1+y^2}\, dx dy$$ donde $R=[-1,0]\times[1,2]$.

# %% [markdown]
# 2. (10 ptos) Usando el principio de Cavalieri, explique usando ideas geométricas como calcular el volumen de la estructura mostrada en la Figura siguiente. Halle el volumen.

# %% [markdown]
# 3. (25 puntos) Aunque el teorema de Fubini se cumple para la mayoría de las funciones
# en la práctica, este ejemplo da una función en la que aparentemente falla puesto que:
#
# $$\int\int_R\, \frac{x-y}{(x+y)^3} \,dx dy=-\frac{1}{2}$$ y
#
# $$\int\int_R\, \frac{x-y}{(x+y)^3} \,dydx=\frac{1}{2},$$
#
# donde $R=[0,1]\times[0,1]$. Explique por qué este ejemplo no contradice el teorema de Fubini.

# %% [markdown]
# 4. (55 ptos) *Integrales iteradas.*
#
#   Para cada una de las integrales dobles mostradas acontinuación:
#
#   * Realice un applet en geogebra que ilustre la región asociada.
#
#   * Plantee la integral correspondiente al cambiar el orden de integración.
#
#   * Calcule por medio de Python los resultados de ambos ordenes de integración verificando así la correctitud de su cambio de orden.
#
# 1.   $$\int_{0}^{\frac{\pi}{2}} \int_{\sin(x)}^{1+\sin(x)} \sin (x^2)y\, dy\, dx.$$
# 2.   $$ \int_{-1}^{1} \int_{y^2-1}^{\sqrt{1-y^2}} (x^2+y)\, dx\, dy.$$
# 3.   $$\int_{e}^{e^2} \int_{\ln{u}}^{1} (v + \ln{u})\, dv\, du.$$
# 4.   $$\int_{0}^1 \int_{x^3}^{x^3+1}  (4x^3+2xy^2)\, dy\, dx.$$

# %% [markdown]
# **La entrega solo se acepta en el formato de un cuaderno Python colab . con el nombre Grupo_numerodelgrupo_Entrega1.ipynb**
