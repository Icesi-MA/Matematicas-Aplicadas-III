# %% [markdown]
# <img src="https://raw.githubusercontent.com/Icesi-MA/Matematicas-Aplicadas-III/main/ICESI_logo.png" width="300" align="center">
#
# # Entrega 7
#
# **Departamento de Ciencias Físicas, Exactas & Energía / FIDCA**
#
# <!--
# Copyright © Angela Villota y Aníbal Sosa.
#
# El contenido textual está licenciado bajo Creative Commons
# Attribution-NonCommercial 4.0 International (CC BY-NC 4.0).
#
# El código y la lógica de los notebooks están licenciados bajo
# PolyForm Noncommercial License 1.0.0.
#
# Consulte el archivo LICENSE del repositorio para conocer los términos completos.
# -->

# %% [markdown]
# <img src=https://www.icesi.edu.co/wp-content/uploads/2024/10/ICESI_logo_prin_descriptor_RGB_NEGATIVO_0924-768x395.png  width="300" height="200" align="center">
#
#
# A continuación se le pide responder por grupo las siguientes preguntas, utilizando una copia del presente cuaderno para consignar todas sus respuestas con el formato requerido.
#
# **Usted debe leer y trabajar en los problemas del cuaderno y traer preguntas para la sesión del miércoles 4 de octubre.**
#
# La entrega está inicialmente para el día **viernes 6 de octubre** y un **grupo**  estará encargado de socializar sus resultados de acuerdo a los lineamientos entregados en la sesión del miércoles anterior.
#
# **<u>Preguntas</u>**
#
# A continuación encuentra separadas por celda cada pregunta, así usted solo debe continuar escribiendo en la celda para dar cada respuesta. No olvide que todas sus respuestas deben ir acompañadas de al menos un argumento geométrico o numérico y uno algebráico o en lenguaje natural.

# %% [markdown]
# 1. (10 ptos) **Formulación de sistemas de ecuaciones lineales**
#
# i. *Interpolación de funciones racionales.* Una función racional de grado dos tiene la forma:
# $$f(t) =\frac{c_1 + c_2t + c_3t^2}{1 + d_1t + d_2t^2}$$
# donde $c_1, c_2, c_3, d_1$ y $ d_2$ son coeficientes. Considere las condiciones de interpolación
# $f(t_i) = y_i;\quad i = 1,...,K;$
# donde $t_i$ y $y_i$ son números dados. Expresar las condiciones de interpolación como un conjunto de ecuaciones lineales
#  con vector de coeficientes  $\mathbf{c} = (c_1, c_2, c_3, d_1, d_2)$, como $A\mathbf{c}  = \mathbf{b}$. Escriba explícitamente la matriz $ A$, el vector $\mathbf{b}$, y sus respectivas dimensiones.
#
# ii. *Mezcla de crudo.* Un conjunto de $K$ diferentes tipos de petróleo crudo se combinan (mezclan) en
# proporciones  $\theta_1,...,\theta_K$. La suma de estas proporciones deben sumar uno; también deben ser no negativss, pero
# se ignorará ese requisito aquí. Asociado con el petróleo crudo tipo $k$ hay un $n-$vector $c_k$ que da su concentración de $n$ constituyentes diferentes, tales como hidrocarburos específicos. Encontrar un conjunto de ecuaciones lineales sobre los coeficientes de mezcla, $A\mathbf{\theta}  = \mathbf{b}$, para garantizar
# que el petróleo crudo mezclado alcance un conjunto objetivo de concentraciones constituyentes, dado por
# el $n-$vector $c^{obj}$. (Incluya la condición  $\theta_1 +...+  \theta_K = 1$  en sus ecuaciones).

# %% [markdown]
# 2. (20 ptos) **Matrices  y solución de sistemas de ecuaciones**
#
# i. *Inversa de una matriz de bloques*. Considere la siguiente matriz de bloques de $(n+1)\times (n+1)$:
#
# $$A=\begin{bmatrix}
# I_n & a\\
# a^T & 0
# \end{bmatrix},$$
#
# donde $a$ es un $n-$vector.
#
# a) ¿Indique qué condiciones debe cumplir el vector $a$ para que $A$ sea una matriz invertible?
#
# b) Asumiendo que la condición en la parte (a) se cumple, halle una expresión para la inversa de $A$.
#
# ii. *Interpolación de funciones racionales.* Encuentre una función racional de la forma
# $$f(t) =\frac{c_1 + c_2t + c_3t^2}{1 + d_1t + d_2t^2}$$
# que satisfaga las siguientes condiciones de interpolación:
# $$f(1) = 2,\quad f(2) = 5,\quad f(3) = 9,\quad f(4) = -1,\quad f(5) = -4.$$
# En el ejercicio 1.i estas condiciones se expresaron como un conjunto de ecuaciones lineales en los coeficientes
# $c_1, c_2, c_3, d_1$ y $ d_2$ aquí le estamos pidiendo que forme y (numéricamente) resuelva el sistema de ecuaciones correspondiente. En un applet de GeoGebra o usando matplotlib dibuje la función racional en el rango $x = 0$ a $x = 6$. Su gráfica debe incluir marcadores en los puntos de interpolación $(1, 2),...,(5.-4)$.

# %% [markdown]
# 3. (20 ptos)  **Implementación de  algoritmos para resolver sistemas de ecuaciones lineales**
#
# Genere una matriz $A$ de tamaño $n \times n$ cuyas entradas sean números enteros aleatorios entre $1$ y $n$, y construya un $n$-vector $\mathbf{b}$ como el producto de la matriz $A$ por un $n$-vector de unos (np.ones(n)). Realice este procedimiento para al menos diez valores de $n$, incrementando de mil en mil, desde $n = 1000$ hasta $n = 10000$.
#
# En otras palabras, debe generar al menos diez sistemas de ecuaciones lineales cuadrados de distinto tamaño, cuya solución exacta es el vector $\mathbf{x} = ones(n)$. Posteriormente, implemente un algoritmo que permita resolver cada sistema utilizando cuatro métodos diferentes: mediante la matriz inversa, $\mathbf{x} = A^{-1}\mathbf{b}$; mediante la factorización $LU$; mediante la factorización $QR$; y finalmente utilizando la función linalg.solve.
#
# **i. *Prueba de tiempo.***
# Utilice una función que permita medir el tiempo de ejecución de cada uno de los cuatro métodos para resolver el sistema $A\mathbf{x} = \mathbf{b}$ de forma independiente. Con esta información, construya una tabla que registre los tiempos de ejecución según el tamaño $n$ del problema. La tabla debe tener 4 filas (una por cada método) y al menos 10 columnas (una por cada valor de $n$ considerado).
#
# **ii. *Precisión de la solución.***
# Dado el tamaño de los sistemas, no es viable verificar visualmente la exactitud de las soluciones obtenidas. Por ello, defina una métrica que permita medir la precisión de cada solución y compárela para cada valor de $n$ y para cada método. Al igual que en el caso anterior, presente los resultados en una tabla de 4 filas y al menos 10 columnas.
#
# **iii. *Gráficos de complejidad y precisión.***
# A partir de los resultados obtenidos en las tablas anteriores, construya dos gráficos: uno que compare la precisión de los métodos y otro que compare sus tiempos de ejecución. En ambos casos, el eje de las abscisas debe corresponder al tamaño del problema $n$.
