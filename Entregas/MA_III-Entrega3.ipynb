# %% [markdown]
# <img src="https://raw.githubusercontent.com/Icesi-MA/Matematicas-Aplicadas-III/main/ICESI_logo.png" width="300" align="center">
#
# # Entrega 3
#
# **Departamento de Ciencias Físicas, Exactas & Energía / FIDCA**
#
# <!--
# Copyright © Angela Villota y Aníbal Sosa.
#
# El contenido textual está licenciado bajo Creative Commons
# Attribution-NonCommercial 4.0 International (CC BY-NC 4.0).
#
# El código y la lógica de los notebooks están licenciados bajo
# PolyForm Noncommercial License 1.0.0.
#
# Consulte el archivo LICENSE del repositorio para conocer los términos completos.
# -->

# %% [markdown]
# A continuación se le pide responder por grupo las siguientes preguntas, utilizando una copia del presente cuaderno para consignar todas sus respuestas con el formato requerido.
#
#
# La entrega será realizada durante la clase del día  **Viernes 6 de Marzo** y un **grupo** podría estar encargado de socializar sus resultados.
#
# **Nivel 3: Colaboración con IAG**
#
# Pueden apoyarse en IAG para redactar, sintetizar o clarificar entregables, siempre y cuando
# modifique activamente el contenido generado y lleve un registro de los prompts utilizados.
# Ejemplo: Uso de IAG para estructurar un Cuaderno Colab que involucre simulación de optimización en
# varias variables, explicando cómo se utilizó la herramienta y qué aportó al proceso.
#
# **<u>Preguntas</u>**
#
# A continuación encuentra separadas por celda cada pregunta, así usted solo debe continuar escribiendo en la celda para dar cada respuesta. No olvide que todas sus respuestas deben ir acompañadas de al menos un argumento geométrico o numérico y uno algebráico o en lenguaje natural.

# %% [markdown]
# 1. (10 ptos) **Integrales triples**
#
# Para cada una de las siguientes integrales usted debe: i. Dibujar en un applet de GeoGebra la región de integración lo mas claro posible. ii. Hallar el valor de la integral numéricamente, es decir, utilizando la libreria scipy.
#
# a. $$\int\int\int_W z\,dz\, dy\, dx,$$
# Donde $W$ es la región acotada por $$x^2+y^2=1; \, x+y+z=3, \, z=0 $$.
#
# b. $$\int\int\int_B x^2 \cos z \,dV.$$
#
# Donde $B$ es la region acotada por $x^2+y^2+z^2\leq 4, \, z^2 \geq x^2+y^2, \, x\geq 0, y\geq 0, \, z\geq 0$.

# %% [markdown]
# 2. (15 ptos) **Geometría de funciones de $\mathbb{R^2}$ a $\mathbb{R^2}$**
#
# (a) Considere la región $D^*$ correspondiente al paralelogramo de vertices $(0, 0), (3, 3), (4, 1),$ y $ (7, 4)$. Explique por qué es posible encontrar una transformación lineal que envíe dicho paralelogramo en el rectángulo $D$ de vértices $(0, 0), (0, 3), (1, 0),$ y $ (1, 3)$.
#
#
# (b) Usando el cambio de variables apropiado, defina una función $f$ y una función $g$ para evaluar una integral de la forma
#
# $$\int\int_D f(x,y)e^{g(x,y)}\, dx dy,$$
# sobre la región $D^*$ en términos de las variables $u$ y $v$.

# %% [markdown]
# 3. (12 ptos)  **Cambio de variables**
#
# (a) Considere la región  $𝑅$ correspondiente paralelogramo que une los puntos $(1,2), (3,4),(4,3),\,$ y  $\,(6,5)$ y la transformación dada por  $𝑢=𝑥−y\,$  y  $\,𝑣=𝑥−3𝑦$. Transforme la región $R$ en una región $R^\ast$ usando la transformación anterior. Dibuje ambas regiones en un mismo applet de GeoGebra.
#
# (b)  Encuentre una transformación lineal de la forma $T(\mathbf{u})=A\mathbf{u}$, donde $A$ es una matriz construida a partir de la solución al sistema $$T(u,v)=\begin{bmatrix}
#   a & b \\
#   c & d
# \end{bmatrix}\begin{bmatrix}
#   u \\
#   v
# \end{bmatrix} = \begin{bmatrix}
#   x \\
#   y
# \end{bmatrix}.$$ Explique por qué tiene sentido resolver el sistema anterior para hallar la matriz $A$.
#
# (c)  Usando el cambio de variables dado por la transformación  $𝑇$, para evaluar una integral de la forma
#
# $$\int\int_R (x-y)\, dx dy$$
# sobre la región $R^\ast$ en términos de las variables $u$ y $v$.

# %% [markdown]
# 4. (13 pts) **Coordenadas cilíndricas**
#
# Plantee la siguiente integral en coordenadas rectangulares y cilíndricas, dibuje la región de integración en un applet de Geogebra, resuelva numericamente las dos integrales para verificar su planteamiento:
#
# i. $$\int\int\int_E \frac{\sqrt{x^2 + y^2 + z^2}}{1 + [x^2 + y^2 + z^2]^2}\, dV,$$ donde $E$ está encerrada por los planos $z=0$  y $z=x+y+5\,$ y los cilíndros $x^2+y^2=4\,$ y $x^2+y^2=9$

# %% [markdown]
# **Recuerde que esta entrega solo será admitida en formato de Colab. El nombre esperado de su archivo con fines de facilitar la identificacion sera *Grupo_numerodelgrupo_Entrega_3.ipynb***
