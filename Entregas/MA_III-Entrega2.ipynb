# %% [markdown]
# <img src="https://raw.githubusercontent.com/Icesi-MA/Matematicas-Aplicadas-III/main/ICESI_logo.png" width="300" align="center">
#
# # Entrega 2
#
# **Departamento de Ciencias Físicas, Exactas & Energía / FIDCA**
#
# <!--
# Copyright © Angela Villota y Aníbal Sosa.
#
# El contenido textual está licenciado bajo Creative Commons
# Attribution-NonCommercial 4.0 International (CC BY-NC 4.0).
#
# El código y la lógica de los notebooks están licenciados bajo
# PolyForm Noncommercial License 1.0.0.
#
# Consulte el archivo LICENSE del repositorio para conocer los términos completos.
# -->

# %% [markdown]
# A continuación se le pide responder por grupo las siguientes preguntas, utilizando una copia del presente cuaderno para consignar todas sus respuestas con el formato requerido.
#
# **Usted debe leer y trabajar en los problemas del cuaderno y traer preguntas para la sesión del Viernes 27 de Febrero.** La entrega total, será el día  **Martes 3 de Marzo** Esta  entrega será socializada en **grupos** recuerde que aunque la entrega es grupal la nota de la socialización será individual.
#
# **Nivel 3: Colaboración con IAG**
#
# Pueden apoyarse en IAG para redactar, sintetizar o clarificar entregables, siempre y cuando
# modifique activamente el contenido generado y lleve un registro de los prompts utilizados.
# Ejemplo: Uso de IAG para estructurar un Cuaderno Colab que involucre simulación de optimización en
# varias variables, explicando cómo se utilizó la herramienta y qué aportó al proceso.

# %% [markdown]
# **<u>Preguntas</u>**
#
# A continuación encuentra separadas por celda cada pregunta, así usted solo debe continuar escribiendo en la celda  para dar cada respuesta. No olvide que todas sus respuestas deben estar bien argumentadas.

# %% [markdown]
# 1. (10 ptos) Para cada una de las siguientes integrales usted debe:
#
# i. Dibujar en un applet de GeoGebra la región de integración lo mas parecido posible.
#
# ii. Debe hallar el valor de la integral numéricamente, es decir, utilizando la libreria scipy.
#
# a.
# $$\int_{0}^{π} \int_{0}^{\sin(x)} y\, dy\, dx.$$
#
# b. Sea $D$ la region acotada por la parabola $x = y^2$ y la recta $y = x.$
#
# $$\int\int_D (2x - y)\,dA.$$

# %% [markdown]
# 2. (15 ptos) Para cada una de las siguientes integrales ustede debe: i. Dibujar en un applet de GeoGebra la región de integración como se sugiere en el punto anterior. ii. Debe reescribir el orden de integración y argumentar por qué dicho cambio facilita o no el cálculo analítico de la integral. iii. Hallar el valor de la integral numéricamente para ambos ordenes de integración y comparar los resultados, esto es, verificar si hay diferencias entre ambos resultados.
#
# a.
# $$\int_{0}^2 \int_{\frac{y}{2}}^{1} y e^{x^{3}}\, dx\, dy.$$
#
# b. $$\int_{-1}^{3} \int_{x^2}^{2x+3} x\, dy\, dx.$$
#
# c. $$\int_{0}^1 \int_{x^4}^{x} (x-1)\, dy\, dx.$$

# %% [markdown]
# 3. (10 ptos)  i. Evalúe $$\int\int_D (x + 2y^{2})\,dx dy,$$ donde $D$ es el  interior del triangulo con  vertices $(1, -1)$, $(4, 2)$ y $(-2, 2)$.
#
# ii. Dado que la  integral doble $$\int\int_D f(x,y)\,dx dy,$$
# de una función continua positiva $f$ es igual a la  integral iterada
# $$\int_0^1\int_y^{\sqrt{2−y^2}} f (x, y)\, dx dy,$$ intercambie el orden de integración.

# %% [markdown]
# *4*. (15 ptos)  **Cambio de variables**
#
# i. Use coordenadas polares para evaluar la integral $$\int\int_D e^{−(x^2+y^2)}\, dA,$$
# donde $D$ es el conjunto de puntos  $(x, y)$ tales que $1 ≤ x^2 +y^2 ≤ 4$.
#
# ii. Explique por qué, si se desea evaluar la integral
#
# $$\int\int_R (x + y)^2e^{x−y}\,dx dy,$$ donde $R$ es la región
# acotada por $x + y = 1, x + y = 4, x − y = −1,$ y
# $x − y = 1$, se debe dividir la región $R$ en mas de una subregión. Utilice un cambio de variable adecuado para transformar la región $R$ en una región $R^*$ que se deje evaluar con una sóla integral doble. Dibuje ambas regiones en un mismo applet de GeoGebra.
#
# iii. Sea $R$ la región dentro de $x^2 + y^2 = 1$, pero fuera de
# $x^2 + y^2 = 2y$ con $x ≥ 0, y ≥ 0$.
#
#   (a) Dibuje en un applet de GeoGebra la región $R$.
#
#   (b) Dibuje en un applet de GeoGebra la región $D$ definida en el plano uv  mediante el cambio de coordenadas $u = x^2 + y^2, v = x^2 + y^2 − 2y$.
#
#   (c) Evalúe $$\int\int_R xe^y\;dx dy$$ usando el cambio de coordenadas $uv$, si y sólo si, con ese cambio de coordenadas se simplifica el cálculo de la integral.

# %% [markdown]
# **Recuerde que esta entrega solo será admitida en formato de Colab. El nombre esperado de su archivo con fines de facilitar la identificacion sera *Grupo_numerodelgrupo_Entrega_2.ipynb***
