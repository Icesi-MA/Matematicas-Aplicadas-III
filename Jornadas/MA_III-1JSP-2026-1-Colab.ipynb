# %% [markdown]
# # Jornada de resolución de problemas: 1JSP 2026 1 Colab
#
# **Departamento de Ciencias Físicas, Exactas & Energía / FIDCA**
#
# <!--
# Copyright © Angela Villota y Aníbal Sosa.
#
# El contenido textual está licenciado bajo Creative Commons
# Attribution-NonCommercial 4.0 International (CC BY-NC 4.0).
#
# El código y la lógica de los notebooks están licenciados bajo
# PolyForm Noncommercial License 1.0.0.
#
# Consulte el archivo LICENSE del repositorio para conocer los términos completos.
# -->

# %% [markdown]
# **Descripción de la jornada**: En esta jornada usted va a encontrar dos problemas. Debe trabajar intentar completar todos los enunciados. Cada problema debe ser abordado en forma individual utilizando todos los recursos que usted disponga (Geogebra, Python, Analítica). La idea central es que elabore sus respuestas o construcciones siguiendo los lineamientos dados a continuación:
#
# 1. Escriba con claridad sus propias ideas.
# 2. Argumente usando lenguaje propio de las matemáticas: geométrico o algebraico, según sea el caso, cada una de sus respuestas.
# 3. Respalde donde considere conveniente sus argumentos geométricos y algebraicos con imágenes o applets diseñadas en alguna de las herramientas que hacen parte de la mochila digital.
# 4.	Resuelva los problemas de manera preferiblemente autónoma; describiendo estrategias para “atacar” el problema, poniendo a prueba sus soluciones y en lo posible planteando nuevos e “interesantes” interrogantes asociados al problema formulado. Si utiliza un resultado o teorema, este debe ser debidamente citado y si es un resultado ajeno a los estudiados en el curso o del texto guía debe proveer la respectiva demostración.
# 5. Nivel 1: No IAG
# La actividad se desarrolla en entornos controlados donde no se permite ningún uso de Inteligencia Artificial Generativa (IAG). El estudiante debe emplear exclusivamente sus propios conocimientos y habilidades.

# %% [markdown]
# ## Integrales triples (Coordenadas Cilíndricas)
#
# ## Problema 2(10pts)
# Sea $W$ el sólido encerrado entre las esferas
# $x^2 + y^2 + z^2 = 49$ y $x^2 + y^2 + z^2 = 64$,
# contenido dentro del cono
# $z = -\sqrt{3(x^2 + y^2)}$
# y limitado por los planos
# $y \le 0$, $x \ge 0$.
#
#
# **Sugerencia:** Analice la simetría del sólido y considere cuidadosamente el orden de integración más conveniente para determinar los límites.
#
# **(b)** Plantee una integral triple en **coordenadas cílindricas** para calcular el volumen del sólido. Explicando por que razón elige los parametros
#
# **(c)** Evalúe numéricamente la integral usando Python y verifique que el valor coincide con la descripción del sólido. Explique claramente el razonamiento utilizado para determinar los límites de integración.

# %%
#@title Sólido W con excesos{ display-mode: "form" }

import IPython.display as IP

iframe = IP.IFrame(
  src="https://www.geogebra.org/3d/p3exnn6j",
  width="1020px",
  height="680px"
  )

IP.display_html(iframe)
# Out:
#         <iframe
#             width="1020px"
#             height="680px"
#             src="https://www.geogebra.org/3d/p3exnn6j"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
#@title Sólido W{ display-mode: "form" }

import IPython.display as IP

iframe = IP.IFrame(
  src="https://www.geogebra.org/calculator/hwcscrba",
  width="1020px",
  height="680px"
  )

IP.display_html(iframe)
# Out:
#         <iframe
#             width="1020px"
#             height="680px"
#             src="https://www.geogebra.org/calculator/hwcscrba"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## Integrales triples (Coordenadas Esféricas y Rectangulares)
#
# ## Problema 3(10pts)
#
# Sea $S$ el sólido encerrado por el plano $y=0$ y los hemisferios
#
# $y = -\sqrt{25 - x^2 - z^2}$, $y = -\sqrt{36 - x^2 - z^2}$.
#
# **(i)** Plantee la integral triple
# $$
# \iiint_S \sqrt{x^2 + y^2} \ast \, z \, dV
# $$
# en **coordenadas esféricas** y en **coordenadas rectangulares** (se sugiere el orden $dydxdz$, pero cualquier orden correcto es válido). Indique claramente el **cambio de variable y el jacobiano**.
#
# **(ii)** Evalúe numéricamente las dos integrales usando Python para verificar que el valor calculado es correcto. Explique el razonamiento que utilizó para los límites de integración y los ángulos en coordenadas esféricas y rectangulares.

# %%
#@title Sólido S{ display-mode: "form" }

import IPython.display as IP

iframe = IP.IFrame(
  src="https://www.geogebra.org/classic/j5mfau56",
  width="620px",
  height="480px"
  )

IP.display_html(iframe)
# Out:
#         <iframe
#             width="620px"
#             height="480px"
#             src="https://www.geogebra.org/classic/j5mfau56"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## Rúbrica de evaluación — Problema 1 (10 puntos)
#
# | Ítem | Descripción | Puntos |
# |------|------------|--------|
# | (b) Integral triple | Integral planteada correctamente en coordenadas cilíndricas, con límites y orden razonable | 7 |
# | (c) Evaluación Python | Código correcto con función y límites adecuados; resultado numérico consistente | 3 |

# %% [markdown]
# | (b) Desglose                                                  | Puntos |
# | ----------------------------------------------------- | ------- |
# | Integral completamente correcta                       | 3       |
# | Dominio (x,z) correcto pero límites de (y) invertidos | 2       |
# | Dominio incorrecto pero idea general correcta         | 1       |
# | Integral incoherente                                  | 0       |

# %% [markdown]
# ## Problema 2 (10 puntos)
#
# | Ítem | Descripción | Puntos |
# |------|------------|--------|
# | (i) Integral triple en coordenadas esféricas | Integral planteada correctamente con función, límites de $\rho, \theta, \phi$, cambio de variable y jacobiano correcto | 4 |
# | (i) Integral triple en coordenadas rectangulares | Integral planteada correctamente con límites adecuados (orden dydxdz sugerido o cualquier orden correcto) | 3 |
# | (ii) Evaluación Python | Código correcto para ambas integrales; resultados numéricos consistentes y coherentes con la geometría del sólido | 3 |
